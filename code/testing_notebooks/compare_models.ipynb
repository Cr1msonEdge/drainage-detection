# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

helper_path = os.path.abspath(os.path.join('../helper'))
if helper_path not in sys.path:
    sys.path.append(helper_path)

# %%
from helper.callbacks.visualize import draw_history_log, draw_resulting_log, draw_metrics, compare_models_sns_barplot
import json

# %%
with open('../helper/callbacks/logs_results/deeplab_hard_test.json', 'r') as inFile:
    deeplab_data = json.load(inFile)    
with open('../helper/callbacks/logs_results/segformer_hard_test.json', 'r') as inFile:
    segformer_data = json.load(inFile)
with open('../helper/callbacks/logs_results/unet_hard_test.json', 'r') as inFile:
    unet_data = json.load(inFile)



hyperparams = {
    'Segformer': segformer_data['model']['hyperparams'],
    'UNet': unet_data['model']['hyperparams'],
    'DeepLab': deeplab_data['model']['hyperparams'],
}

metrics = {
    'Segformer': segformer_data['data'],
    'UNet': unet_data['data'],
    'DeepLab': deeplab_data['data'],
}

compare_models_sns_barplot(list(hyperparams.keys()), hyperparams_dict=hyperparams, metrics_dict=metrics)
# Out:
# c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
